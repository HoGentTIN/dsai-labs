# %% [markdown]
# ## Info about the exam
# * [Examenmededeling NL](https://github.com/HoGentTIN/dsai-labs/blob/main/0-info/Examenmededeling%20Mei%202026%20NLL.pdf)
# * [Exam announcement EN](https://github.com/HoGentTIN/dsai-labs/blob/main/0-info/Exam%20announcement%20May%202026%20EN.pdf)
# * [Instructies examen met schermopname](https://github.com/HoGentTIN/dsai-labs/blob/main/0-info/instructies_examen_met_schermopname.pdf)
# * [Exam recording instructions](https://github.com/HoGentTIN/dsai-labs/blob/main/0-info/Exam%20recording%20instructions%20EN.pdf)
#
# # Course Introduction
#
# ## Learning goals
# * Descriptive Statistics
#     - Knows some descriptive measures for data (central tendency,
# dispersion).
#     - Can calculate some descriptive measures for data using statistical software (Python).
# * Data visualisation
#     - Knows different types of plots to represent data visually.
#     - Can visualize data using appropriate plots
# * Probability
#     - Knows the basic rules with regard to calculating with probabilities.
#     - Knows the properties of some important probability distribution
# * Bivariate analysis
#     - Can quantify and appropriately test the relationship between two
# variables.
#     - Can construct a simple linear model to show the relationship between two or more variables.
# * Time series analysis
#     - Can discuss some common models to predict time series and/or
# detect anomalies.
#     - Can indicate the importance of testing the
#
#
# ## Course contents
#
# * Introduction, sampling
# * Univariate analysis
# * Probability, central limit theorem, statistical testing
# * Bivariate analysis: qualitative variables
# * Bivariate analysis: qualitative vs. quantitative variables
# * Bivariate analysis: quantitative variables
# * Time series analysis
#
# ## Calendar
#
# | Week     | Subject |
# |----------|----------|
# | 1     | Course intro, sampling       |
# | 2     | Univariate analysis       |
# | 3   | Probability |
# | 4 | Central Limit Theorem |
# | 5 | Statistical testing: z-test + Student t-test |
# | 6 |  Bivariate analysis: 𝜒² test, Cramér’s V |
# | 7 |  Bivariate analysis: 𝜒² test, Cramér’s V |
# | 8 |   Bivariate analysis: qual. vs. quant. variable -> two-sample 𝑡-test, effect size |
# | -- | Easter holiday |
# | 9 | Bivariate analysis: quantitative variables -> Linear regression |
# | 10 | Time series analysis |
# | 11 | Time series analysis |
# | 12 | Sample Exam |
#
# ## Assessment
#
# ! under reserve!
#
# ! Further details will be clearly communicated prior to the exam.!
# * Written exam
# * On your computer
# * 2 parts
#     - ANS
#     - Jupyter Notebook
#     Fill out responses in the notebook & hand it in
# * Open book
#     - ANS: formularium?
#     - Jupyter Notebook?
#         - Course material and slides, learning path on Chamilo
#         - Textbook (PDF, printed)
#         - Your personal notes, solutions to exercises
#         - Software for statistical analysis (Google Colab, Python, VS Code)
#
# ## Data Science & AI Glossary
# https://hogenttin.github.io/dsai-glossary/
#
# ## Asking questions
# Before sending us emails to ask questions about the course PLEASE use the Teams channel
#
# ## Contactmoments TIAO students --> see Teams meetings
# * 26 februari 2026 - 19h00 tot 19h30
# * 26 maart 2026 - 19h00 tot 19h30
# * 7 mei 2026 - 19h00 tot 19h30
